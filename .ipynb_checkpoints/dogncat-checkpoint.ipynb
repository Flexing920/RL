# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
base_path = os.getcwd()
file_path = "data"
CATEGORIES = ['Dog', 'Cat'] # 0 Dog; 1 Cat
data_path = os.path.join(base_path, file_path)

# %%
for c in CATEGORIES:
    path = os.path.join(data_path, c)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        plt.show()
        break
print(img_array)
# Out:
# [[ 81  74  75 ...  74  73  72]
#  [ 74  74  80 ...  74  73  73]
#  [ 73  80  89 ...  74  74  73]
#  ...
#  [156 160 150 ... 173 158 160]
#  [150 155 154 ... 179 167 174]
#  [155 158 160 ... 175 165 176]]

# %%
IMG_SIZE = 50

new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_array, cmap='gray')
plt.show()

# %%
training_data = []
training_data_count = [0, 0]
def create_training_data():
    for category in CATEGORIES:
        path = os.path.join(data_path, category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
                training_data.append([new_array, class_num])
                training_data_count[class_num] += 1
            except Exception as e:
                pass
create_training_data()

# %%
print(len(training_data))
print(training_data_count)
# Out:
# 24946
# [12470, 12476]

# %%
import random
random.shuffle(training_data)

# %%
X = []
y = []
for features, label in training_data:
    X.append(features)
    y.append(label)

# %%
# not sure why we need to do this
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
print(X.shape)
# Out:
# (24946, 50, 50, 1)

# %%
import pickle
pickle_out = open("X.pickle", "wb")
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open("y.pickle", "wb")
pickle.dump(y, pickle_out)
pickle_out.close()
